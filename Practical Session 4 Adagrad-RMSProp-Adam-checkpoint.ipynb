# %% [markdown]
# ## Practical Work 4

# %% [markdown]
# For this practical work, the student will have to develop a Python program that is able to implement the accelerated gradient descent methods with adaptive learning rate <b>(Adagrad, RMSProp, and Adam)</b> in order to achieve the linear regression of a set of datapoints.

# %% [markdown]
# #### Import numpy, matplotlib.pyplot and make it inline

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# To have a dataset or set of data points, the student must generate a pair of arrays <b>X</b> and <b>y</b> with the values in <b>X</b> equally distributed between <b>0</b> and <b>20</b> and the values in <b>y</b> such that:
# <b>yi = a*xi + b (and a = -1, b = 2)</b>

# %%
x = np.linspace(0,20,50)
y = -2 * x +1
x = x.reshape(x.shape[0],1)
ones = np.ones(x.shape[0]).reshape((x.shape[0], 1))
x = np.hstack([ones,x])

# %% [markdown]
# #### Plot your data points.

# %%
plt.scatter(x[:,1],y)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Adagrad

# %% [markdown]
# ### For a single variable linear regression ML model, build a function to find the optimum Theta_0 and Theta_1 parameters using Adagrad optimization algorithm.
# #### The funtion should have the following input parameters:
# ##### 1. Input data as a matrix (or vector based on your data).
# ##### 2. Target label as a vector.
# ##### 3. Learning rate.
# ##### 4. Epsilon.
# ##### 5. Maximum number of iterations (Epochs).
# #### The funtion should return the following outputs:
# ##### 1. All predicted Theta_0 in all iterations.
# ##### 2. All predicted Theta_1 in all iterations.
# ##### 3. Corresponding loss for each Theta_0 and Theta_1 predictions.
# ##### 4.All hypothesis outputs (prdicted labels) for each Theta_0 and Theta_1 predictions.
# ##### 5.Final Optimum values of Theta_0 and Theta_1.
# #### Choose the suitable number of iterations, learning rate, Epsilon, and stop criteria.
# #### Calculate r2 score. Shouldn't below 0.9
# #### Plot the required curves (loss-epochs, loss-theta0, loss-theta1, all fitted lines per epoch (single graph), best fit line)
# #### Try different values of the huperparameters and see the differnce in your results.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def Adagrad(x, y, alpha, epsoln, number_of_iterations):
   
    theta = np.random.random(2)
    cost_array =[0]
    h_theta_array = [0]
    theta_array =[[0,0]]
    count = 0
    vt_1 = 0

    for i in range(number_of_iterations):
        
        h_theta = x @ theta
        gradient = (1/len(y))*(h_theta - y ) @ x
        vt = vt_1 + (gradient ** 2)
        theta = theta - alpha / (np.sqrt(vt)+epsoln)  * gradient
        cost = (1/len(y)) * sum((h_theta - y)**2)
        
        theta_array.append(theta)
        cost_array.append(cost)
        h_theta_array.append(h_theta)
        count += 1
        
        if np.linalg.norm(gradient,2) < 1e-3 :
            break
        
        if abs(cost_array[-1] - cost_array[-2]) < 1e-6 :
            break

    y_pred = x @ theta
    
    return theta_array, cost_array, theta, h_theta_array, y_pred, count

# %%
theta_array, cost_array, theta, h_theta_array, y_pred, count =Adagrad(x, y, .001, 1e-8, 10000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 4450

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.999978646716761

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
weights = np.array(theta_array)
print(weights.shape)
plt.plot(weights[: , 0][1:], cost_array[1:] , label = 'theta0')
plt.plot(weights[: , 1][1:], cost_array[1:], label = 'theta1')
plt.title('Theta Vs cost Function')
plt.xlabel('Theta')
plt.ylabel('Cost Function') 
plt.legend()
# Out:
# (4451, 2)

# %%
plt.scatter(x[:,1], y)
for theta in weights:
    plt.plot(x[:,1] ,  x @ theta , color = 'r')

plt.title('All regression lines')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
#trying diferent parameter
theta_array, cost_array, theta, h_theta_array, y_pred, count =Adagrad(x, y, .0011, 1e-8, 10000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 3491

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.9999023069255605

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
weights = np.array(theta_array)
print(weights.shape)
plt.plot(weights[: , 0][1:], cost_array[1:] , label = 'theta0')
plt.plot(weights[: , 1][1:], cost_array[1:], label = 'theta1')
plt.title('Theta Vs cost Function')
plt.xlabel('Theta')
plt.ylabel('Cost Function') 
plt.legend()
# Out:
# (3492, 2)

# %%
plt.scatter(x[:,1], y)
for theta in weights:
    plt.plot(x[:,1] ,  x @ theta , color = 'r')

plt.title('All regression lines')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %% [markdown]
# ## RMSProp

# %% [markdown]
# ### Update the previos implementation to be RMSProp.
# #### Compare your results with Adagrad results.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def RMSProp(x, y, alpha, epsoln, beta, number_of_iterations):
    
    theta = np.random.random(2)
    cost_array =[0]
    h_theta_array = [0]
    theta_array =[[0,0]]
    count = 0
    vt_1 = 0

    for i in range(number_of_iterations):
        
        h_theta = x @ theta
        gradient = (1/len(y))*(h_theta - y ) @ x
        vt = (beta * vt_1) + (1-beta)*(gradient ** 2)
        theta = theta - alpha / (np.sqrt(vt)+epsoln)  * gradient
        cost = (1/len(y)) * sum((h_theta - y)**2)
        
        theta_array.append(theta)
        cost_array.append(cost)
        h_theta_array.append(h_theta)
        count += 1
        
        if np.linalg.norm(gradient,2) < 1e-3 :
            break
        
        if abs(cost_array[-1] - cost_array[-2]) < 1e-6 :
            break

    y_pred = x @ theta
    
    return theta_array, cost_array,h_theta_array, y_pred, count

# %%
theta_array, cost_array, h_theta_array, y_pred, count = RMSProp(x, y, .00016, 1e-8, .85, 15000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 11311

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.9999733419556817

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
weights = np.array(theta_array)
print(weights.shape)
plt.plot(weights[: , 0][1:], cost_array[1:] , label = 'theta0')
plt.plot(weights[: , 1][1:], cost_array[1:], label = 'theta1')
plt.title('Theta Vs cost Function')
plt.xlabel('Theta')
plt.ylabel('Cost Function') 
plt.legend()
# Out:
# (11312, 2)

# %%
plt.scatter(x[:,1], y)
for theta in weights:
    plt.plot(x[:,1] ,  x @ theta , color = 'r')

plt.title('All regression lines')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
#trying different parameters
theta_array, cost_array, h_theta_array, y_pred, count = RMSProp(x, y, .001, 1e-8, .5, 15000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 2642

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.9998290106195233

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
weights = np.array(theta_array)
print(weights.shape)
plt.plot(weights[: , 0][1:], cost_array[1:] , label = 'theta0')
plt.plot(weights[: , 1][1:], cost_array[1:], label = 'theta1')
plt.title('Theta Vs cost Function')
plt.xlabel('Theta')
plt.ylabel('Cost Function') 
plt.legend()
# Out:
# (2643, 2)

# %%
plt.scatter(x[:,1], y)
for theta in weights:
    plt.plot(x[:,1] ,  x @ theta , color = 'r')

plt.title('All regression lines')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %% [markdown]
# ## Adam

# %% [markdown]
# ### Update the previos implementation to be Adam.
# #### Compare your results with Adagrad and RMSProp results.

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %%
def Adam(x, y, alpha, epsoln, beta, gamma, number_of_iterations):
    
    
    theta = np.random.random(2)
    cost_array =[0]
    h_theta_array = [0]
    theta_array =[[0,0]]
    count = 0
    vt_1 = 0
    mt_1 = 0

    for i in range(number_of_iterations):
        
        h_theta = x @ theta
        gradient = (1/len(y))*(h_theta - y ) @ x
        vt = (beta * vt_1) + (1-beta)*(gradient ** 2)
        mt = gamma * mt_1 + (1-gamma) * gradient
        
        vt = vt / (1-beta ** (i+1))
        mt = mt / (1- gamma ** (i+1))
        
        theta = theta - alpha / (np.sqrt(vt)+epsoln)  * mt
        cost = (1/len(y)) * sum((h_theta - y)**2)
        
        theta_array.append(theta)
        cost_array.append(cost)
        h_theta_array.append(h_theta)
        count += 1
        
        if np.linalg.norm(gradient,2) < 1e-3 :
            break
        
        if abs(cost_array[-1] - cost_array[-2]) < 1e-6 :
            break

    y_pred = x @ theta
    
    return theta_array, cost_array,h_theta_array, y_pred, count

# %%
theta_array, cost_array,h_theta_array, y_pred, count = Adam(x, y, .001, 1e-8, .98, .9, 15000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 6738

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.9999580454099881

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
weights = np.array(theta_array)
print(weights.shape)
plt.plot(weights[: , 0][1:], cost_array[1:] , label = 'theta0')
plt.plot(weights[: , 1][1:], cost_array[1:], label = 'theta1')
plt.title('Theta Vs cost Function')
plt.xlabel('Theta')
plt.ylabel('Cost Function') 
plt.legend()
# Out:
# (6739, 2)

# %%
plt.scatter(x[:,1], y)
for theta in weights:
    plt.plot(x[:,1] ,  x @ theta , color = 'r')

plt.title('All regression lines')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
#trying different parameter
theta_array, cost_array,h_theta_array, y_pred, count = Adam(x, y, .001, 1e-8, .3, .3, 15000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 5358

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.9999265801492689

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
plt.scatter(x[:,1], y)
for theta in weights:
    plt.plot(x[:,1] ,  x @ theta , color = 'r')

plt.title('All regression lines')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
#comparing between 3 algorithms

# %%
#adagrad
theta_array, cost_array, theta, h_theta_array, y_pred, count =Adagrad(x, y, .001, 1e-8, 10000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 10000

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.9999969934054199

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
#Rmsprop
theta_array, cost_array, h_theta_array, y_pred, count = RMSProp(x, y, .001, 1e-8, .5, 10000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 3639

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.9998922180317504

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %%
#adam
theta_array, cost_array,h_theta_array, y_pred, count = Adam(x, y, .001, 1e-8, .5, .3, 10000)

# %%
print(f'Number of iterations: {count}')
# Out:
# Number of iterations: 5673

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.9999474383261514

# %%
plt.plot(np.arange(count), cost_array[1:])
plt.title('Epocks Vs cost Function')
plt.xlabel('Numbers of Epochs')
plt.ylabel('Cost Function')
# Out:
# Text(0, 0.5, 'Cost Function')

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], y_pred, 'r')
plt.title('Real Output Vs Predicted Output')
plt.xlabel('X Values')
plt.ylabel('Y Values')
# Out:
# Text(0, 0.5, 'Y Values')

# %% [markdown]
# ## Congratulations
# ![image.png](attachment:image.png)
